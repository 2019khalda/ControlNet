# %%
# !git clone https://github.com/huggingface/diffusers
# Out:
# Cloning into 'diffusers'...
# remote: Enumerating objects: 21463, done.
# remote: Counting objects: 100% (437/437), done.
# remote: Compressing objects: 100% (260/260), done.
# remote: Total 21463 (delta 266), reused 280 (delta 151), pack-reused 21026
# Receiving objects: 100% (21463/21463), 13.96 MiB | 27.22 MiB/s, done.
# Resolving deltas: 100% (15207/15207), done.

# %%
# !pip install git+https://github.com/huggingface/diffusers
# !pip install -U -r diffusers/examples/dreambooth/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/huggingface/diffusers
#   Cloning https://github.com/huggingface/diffusers to /tmp/pip-req-build-pwu739o3
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers /tmp/pip-req-build-pwu739o3
#   Resolved https://github.com/huggingface/diffusers to commit 2ea1da89ab42bde69caad909048925ca99873400
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from diffusers==0.15.0.dev0) (2022.6.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.8/dist-packages (from diffusers==0.15.0.dev0) (8.4.0)
# Collecting huggingface-hub>=0.10.0
#   Using cached huggingface_hub-0.12.1-py3-none-any.whl (190 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from diffusers==0.15.0.dev0) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from diffusers==0.15.0.dev0) (2.25.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from diffusers==0.15.0.dev0) (6.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from diffusers==0.15.0.dev0) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.10.0->diffusers==0.15.0.dev0) (4.5.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.10.0->diffusers==0.15.0.dev0) (6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.10.0->diffusers==0.15.0.dev0) (23.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.10.0->diffusers==0.15.0.dev0) (4.64.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->diffusers==0.15.0.dev0) (3.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->diffusers==0.15.0.dev0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->diffusers==0.15.0.dev0) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->diffusers==0.15.0.dev0) (1.26.14)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->diffusers==0.15.0.dev0) (4.0.0)
# Building wheels for collected packages: diffusers
#   Building wheel for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.15.0.dev0-py3-none-any.whl size=737783 sha256=e19ae8306484ebd6d493b3aae91eea96faa8500c5ad898562150d3839a4463df
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cyuh6n2o/wheels/c6/77/b7/6d22ce35b79fbe5cc7513554d61c918bb4bf3eac5fdb8ae787
# Successfully built diffusers
# Installing collected packages: huggingface-hub, diffusers
# Successfully installed diffusers-0.15.0.dev0 huggingface-hub-0.12.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting accelerate
#   Downloading accelerate-0.16.0-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 KB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: torchvision in /usr/local/lib/python3.8/dist-packages (from -r diffusers/examples/dreambooth/requirements.txt (line 2)) (0.14.1+cu116)
# Collecting transformers>=4.25.1
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 38.9 MB/s eta 0:00:00
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 KB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.8/dist-packages (from -r diffusers/examples/dreambooth/requirements.txt (line 5)) (2.11.2)
# Collecting tensorboard
#   Downloading tensorboard-2.12.0-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 66.1 MB/s eta 0:00:00
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.8/dist-packages (from -r diffusers/examples/dreambooth/requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from accelerate->-r diffusers/examples/dreambooth/requirements.txt (line 1)) (1.22.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.8/dist-packages (from accelerate->-r diffusers/examples/dreambooth/requirements.txt (line 1)) (5.4.8)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from accelerate->-r diffusers/examples/dreambooth/requirements.txt (line 1)) (1.13.1+cu116)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from accelerate->-r diffusers/examples/dreambooth/requirements.txt (line 1)) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from accelerate->-r diffusers/examples/dreambooth/requirements.txt (line 1)) (23.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchvision->-r diffusers/examples/dreambooth/requirements.txt (line 2)) (2.25.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torchvision->-r diffusers/examples/dreambooth/requirements.txt (line 2)) (4.5.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision->-r diffusers/examples/dreambooth/requirements.txt (line 2)) (8.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.8/dist-packages (from transformers>=4.25.1->-r diffusers/examples/dreambooth/requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers>=4.25.1->-r diffusers/examples/dreambooth/requirements.txt (line 3)) (2022.6.2)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 104.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers>=4.25.1->-r diffusers/examples/dreambooth/requirements.txt (line 3)) (4.64.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers>=4.25.1->-r diffusers/examples/dreambooth/requirements.txt (line 3)) (3.9.0)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.8/dist-packages (from ftfy->-r diffusers/examples/dreambooth/requirements.txt (line 4)) (0.2.6)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.8/dist-packages (from tensorboard->-r diffusers/examples/dreambooth/requirements.txt (line 5)) (3.19.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.8/dist-packages (from tensorboard->-r diffusers/examples/dreambooth/requirements.txt (line 5)) (0.38.4)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.8/dist-packages (from tensorboard->-r diffusers/examples/dreambooth/requirements.txt (line 5)) (1.51.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard->-r diffusers/examples/dreambooth/requirements.txt (line 5)) (0.4.6)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.0-py3-none-manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 104.3 MB/s eta 0:00:00
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard->-r diffusers/examples/dreambooth/requirements.txt (line 5)) (2.16.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard->-r diffusers/examples/dreambooth/requirements.txt (line 5)) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard->-r diffusers/examples/dreambooth/requirements.txt (line 5)) (1.8.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.8/dist-packages (from tensorboard->-r diffusers/examples/dreambooth/requirements.txt (line 5)) (1.4.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard->-r diffusers/examples/dreambooth/requirements.txt (line 5)) (2.2.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard->-r diffusers/examples/dreambooth/requirements.txt (line 5)) (57.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from Jinja2->-r diffusers/examples/dreambooth/requirements.txt (line 6)) (2.1.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r diffusers/examples/dreambooth/requirements.txt (line 5)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r diffusers/examples/dreambooth/requirements.txt (line 5)) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r diffusers/examples/dreambooth/requirements.txt (line 5)) (5.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r diffusers/examples/dreambooth/requirements.txt (line 5)) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->-r diffusers/examples/dreambooth/requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard->-r diffusers/examples/dreambooth/requirements.txt (line 5)) (6.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision->-r diffusers/examples/dreambooth/requirements.txt (line 2)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision->-r diffusers/examples/dreambooth/requirements.txt (line 2)) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision->-r diffusers/examples/dreambooth/requirements.txt (line 2)) (1.26.14)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision->-r diffusers/examples/dreambooth/requirements.txt (line 2)) (4.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->-r diffusers/examples/dreambooth/requirements.txt (line 5)) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->-r diffusers/examples/dreambooth/requirements.txt (line 5)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->-r diffusers/examples/dreambooth/requirements.txt (line 5)) (3.2.2)
# Installing collected packages: tokenizers, tensorboard-data-server, ftfy, accelerate, transformers, tensorboard
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.6.1
#     Uninstalling tensorboard-data-server-0.6.1:
#       Successfully uninstalled tensorboard-data-server-0.6.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.11.2
#     Uninstalling tensorboard-2.11.2:
#       Successfully uninstalled tensorboard-2.11.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.11.0 requires tensorboard<2.12,>=2.11, but you have tensorboard 2.12.0 which is incompatible.
# Successfully installed accelerate-0.16.0 ftfy-6.1.1 tensorboard-2.12.0 tensorboard-data-server-0.7.0 tokenizers-0.13.2 transformers-4.26.1

# %%
from accelerate.utils import write_basic_config
write_basic_config()
# Out:
# PosixPath('/root/.cache/huggingface/accelerate/default_config.yaml')

# %%
# !pip install xformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting xformers
#   Downloading xformers-0.0.16-cp38-cp38-manylinux2014_x86_64.whl (50.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 MB 13.1 MB/s eta 0:00:00
# Requirement already satisfied: torch==1.13.1 in /usr/local/lib/python3.8/dist-packages (from xformers) (1.13.1+cu116)
# Collecting pyre-extensions==0.0.23
#   Downloading pyre_extensions-0.0.23-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from xformers) (1.22.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from pyre-extensions==0.0.23->xformers) (4.5.0)
# Collecting typing-inspect
#   Downloading typing_inspect-0.8.0-py3-none-any.whl (8.7 kB)
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: mypy-extensions, typing-inspect, pyre-extensions, xformers
# Successfully installed mypy-extensions-1.0.0 pyre-extensions-0.0.23 typing-inspect-0.8.0 xformers-0.0.16

# %%
# !pip install bitsandbytes
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.37.0-py3-none-any.whl (76.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.3/76.3 MB 11.1 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.37.0

# %%
# %%bash
# export MODEL_NAME="runwayml/stable-diffusion-v1-5"
# export INSTANCE_DIR="/content/drive/MyDrive/Colab_Notebooks/Chebakia"
# export OUTPUT_DIR="/content/drive/MyDrive/Colab_Notebooks"
#
# accelerate launch --mixed_precision="fp16" /content/diffusers/examples/dreambooth/train_dreambooth.py \
#   --pretrained_model_name_or_path=$MODEL_NAME  \
#   --instance_data_dir=$INSTANCE_DIR \
#   --output_dir=$OUTPUT_DIR \
#   --instance_prompt="a photo of a cookie" \
#   --resolution=512 \
#   --train_batch_size=1 \
#   --learning_rate=5e-6 \
#   --lr_scheduler="constant" \
#   --lr_warmup_steps=0 \
#   --max_train_steps=400\
#   --checkpointing_steps=500\
#   --enable_xformers_memory_efficient_attention\
#   --set_grads_to_none \
#   --use_8bit_adam \
#   --mixed_precision=fp16\
#   --gradient_accumulation_steps=2 --gradient_checkpointing
# Out:
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ================================================================================
# 2023-03-05 16:23:35.788556: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-05 16:23:37.590951: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-05 16:23:37.591586: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-05 16:23:37.591608: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-03-05 16:23:43.114633: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-05 16:23:43.114820: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-05 16:23:43.114846: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# A matching Triton is not available, some optimizations will not be enabled.
# Error caught was: No module named 'triton'
# /usr/local/lib/python3.8/dist-packages/accelerate/accelerator.py:231: FutureWarning: `logging_dir` is deprecated and will be removed in version 0.18.0 of 🤗 Accelerate. Use `project_dir` instead.
#   warnings.warn(
# 03/05/2023 16:23:48 - INFO - __main__ - Distributed environment: NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
# Mixed precision type: fp16
#
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# {'clip_sample_range', 'prediction_type', 'variance_type'} was not found in config. Values will be initialized to default values.
# {'scaling_factor'} was not found in config. Values will be initialized to default values.
# {'use_linear_projection', 'timestep_post_act', 'num_class_embeds', 'dual_cross_attention', 'time_cond_proj_dim', 'only_cross_attention', 'conv_out_kernel', 'class_embed_type', 'resnet_time_scale_shift', 'conv_in_kernel', 'upcast_attention', 'time_embedding_type', 'projection_class_embeddings_input_dim', 'mid_block_type'} was not found in config. Values will be initialized to default values.
# /content/diffusers/examples/dreambooth/train_dreambooth.py:667: DeprecationWarning: The 'warn' method is deprecated, use 'warning' instead
#   logger.warn(
# 03/05/2023 16:23:58 - WARNING - __main__ - xFormers 0.0.16 cannot be used for training in some GPUs. If you observe problems during training, please update xFormers to at least 0.0.17. See https://huggingface.co/docs/diffusers/main/en/optimization/xformers for more details.
# 03/05/2023 16:24:07 - INFO - __main__ - ***** Running training *****
# 03/05/2023 16:24:07 - INFO - __main__ -   Num examples = 4
# 03/05/2023 16:24:07 - INFO - __main__ -   Num batches each epoch = 4
# 03/05/2023 16:24:07 - INFO - __main__ -   Num Epochs = 200
# 03/05/2023 16:24:07 - INFO - __main__ -   Instantaneous batch size per device = 1
# 03/05/2023 16:24:07 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 2
# 03/05/2023 16:24:07 - INFO - __main__ -   Gradient Accumulation steps = 2
# 03/05/2023 16:24:07 - INFO - __main__ -   Total optimization steps = 400
# Steps: 100%|██████████| 400/400 [09:30<00:00,  1.41s/it, loss=0.252, lr=5e-6]
# Downloading (…)ain/model_index.json: 100%|██████████| 543/543 [00:00<00:00, 158kB/s]
#
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
#
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
#
#
# Downloading (…)rocessor_config.json: 100%|██████████| 342/342 [00:00<00:00, 25.7kB/s]
#
#
#
# Downloading (…)_checker/config.json: 100%|██████████| 4.72k/4.72k [00:00<00:00, 674kB/s]
#
# Fetching 15 files:   7%|▋         | 1/15 [00:00<00:04,  3.39it/s]
#
# Downloading (…)"pytorch_model.bin";:   1%|          | 10.5M/1.22G [00:00<00:22, 54.5MB/s]
#
# Downloading (…)"pytorch_model.bin";:   2%|▏         | 21.0M/1.22G [00:00<00:18, 64.4MB/s]
#
# Downloading (…)"pytorch_model.bin";:   3%|▎         | 31.5M/1.22G [00:00<00:17, 69.2MB/s]
#
# Downloading (…)"pytorch_model.bin";:   3%|▎         | 41.9M/1.22G [00:00<00:15, 74.2MB/s]
#
# Downloading (…)"pytorch_model.bin";:   4%|▍         | 52.4M/1.22G [00:00<00:14, 77.9MB/s]
#
# Downloading (…)"pytorch_model.bin";:   5%|▌         | 62.9M/1.22G [00:00<00:14, 79.2MB/s]
#
# Downloading (…)"pytorch_model.bin";:   6%|▌         | 73.4M/1.22G [00:00<00:13, 81.7MB/s]
#
# Downloading (…)"pytorch_model.bin";:   7%|▋         | 83.9M/1.22G [00:01<00:14, 77.9MB/s]
#
# Downloading (…)"pytorch_model.bin";:   8%|▊         | 94.4M/1.22G [00:01<00:14, 77.2MB/s]
#
# Downloading (…)"pytorch_model.bin";:   9%|▊         | 105M/1.22G [00:01<00:14, 78.5MB/s]
#
# Downloading (…)"pytorch_model.bin";:   9%|▉         | 115M/1.22G [00:01<00:14, 73.5MB/s]
#
# Downloading (…)"pytorch_model.bin";:  10%|█         | 126M/1.22G [00:01<00:15, 72.2MB/s]
#
# Downloading (…)"pytorch_model.bin";:  11%|█         | 136M/1.22G [00:01<00:14, 75.6MB/s]
#
# Downloading (…)"pytorch_model.bin";:  12%|█▏        | 147M/1.22G [00:01<00:13, 78.4MB/s]
#
# Downloading (…)"pytorch_model.bin";:  13%|█▎        | 157M/1.22G [00:02<00:13, 75.7MB/s]
#
# Downloading (…)"pytorch_model.bin";:  14%|█▍        | 168M/1.22G [00:02<00:13, 76.7MB/s]
#
# Downloading (…)"pytorch_model.bin";:  15%|█▍        | 178M/1.22G [00:02<00:13, 75.4MB/s]
#
# Downloading (…)"pytorch_model.bin";:  16%|█▌        | 189M/1.22G [00:02<00:14, 72.7MB/s]
#
# Downloading (…)"pytorch_model.bin";:  16%|█▋        | 199M/1.22G [00:02<00:13, 73.4MB/s]
#
# Downloading (…)"pytorch_model.bin";:  17%|█▋        | 210M/1.22G [00:02<00:13, 75.9MB/s]
#
# Downloading (…)"pytorch_model.bin";:  18%|█▊        | 220M/1.22G [00:02<00:12, 77.8MB/s]
#
# Downloading (…)"pytorch_model.bin";:  19%|█▉        | 231M/1.22G [00:03<00:12, 80.6MB/s]
#
# Downloading (…)"pytorch_model.bin";:  20%|█▉        | 241M/1.22G [00:03<00:11, 81.4MB/s]
#
# Downloading (…)"pytorch_model.bin";:  21%|██        | 252M/1.22G [00:03<00:11, 80.6MB/s]
#
# Downloading (…)"pytorch_model.bin";:  22%|██▏       | 262M/1.22G [00:03<00:12, 78.1MB/s]
#
# Downloading (…)"pytorch_model.bin";:  22%|██▏       | 273M/1.22G [00:03<00:11, 79.9MB/s]
#
# Downloading (…)"pytorch_model.bin";:  23%|██▎       | 283M/1.22G [00:03<00:12, 77.5MB/s]
#
# Downloading (…)"pytorch_model.bin";:  24%|██▍       | 294M/1.22G [00:03<00:11, 78.9MB/s]
#
# Downloading (…)"pytorch_model.bin";:  25%|██▌       | 304M/1.22G [00:03<00:11, 82.0MB/s]
#
# Downloading (…)"pytorch_model.bin";:  26%|██▌       | 315M/1.22G [00:04<00:10, 82.7MB/s]
#
# Downloading (…)"pytorch_model.bin";:  27%|██▋       | 325M/1.22G [00:04<00:10, 81.9MB/s]
#
# Downloading (…)"pytorch_model.bin";:  28%|██▊       | 336M/1.22G [00:04<00:11, 76.7MB/s]
#
# Downloading (…)"pytorch_model.bin";:  28%|██▊       | 346M/1.22G [00:04<00:11, 75.7MB/s]
#
# Downloading (…)"pytorch_model.bin";:  29%|██▉       | 357M/1.22G [00:04<00:11, 75.1MB/s]
#
# Downloading (…)"pytorch_model.bin";:  30%|███       | 367M/1.22G [00:04<00:11, 77.1MB/s]
#
# Downloading (…)"pytorch_model.bin";:  31%|███       | 377M/1.22G [00:04<00:10, 79.8MB/s]
#
# Downloading (…)"pytorch_model.bin";:  32%|███▏      | 388M/1.22G [00:05<00:10, 79.3MB/s]
#
# Downloading (…)"pytorch_model.bin";:  33%|███▎      | 398M/1.22G [00:05<00:10, 76.6MB/s]
#
# Downloading (…)"pytorch_model.bin";:  34%|███▎      | 409M/1.22G [00:05<00:10, 78.3MB/s]
#
# Downloading (…)"pytorch_model.bin";:  34%|███▍      | 419M/1.22G [00:05<00:10, 74.9MB/s]
#
# Downloading (…)"pytorch_model.bin";:  35%|███▌      | 430M/1.22G [00:05<00:10, 78.0MB/s]
#
# Downloading (…)"pytorch_model.bin";:  36%|███▌      | 440M/1.22G [00:05<00:09, 79.8MB/s]
#
# Downloading (…)"pytorch_model.bin";:  37%|███▋      | 451M/1.22G [00:05<00:10, 76.4MB/s]
#
# Downloading (…)"pytorch_model.bin";:  38%|███▊      | 461M/1.22G [00:05<00:09, 79.4MB/s]
#
# Downloading (…)"pytorch_model.bin";:  39%|███▉      | 472M/1.22G [00:06<00:09, 82.6MB/s]
#
# Downloading (…)"pytorch_model.bin";:  40%|███▉      | 482M/1.22G [00:06<00:08, 82.3MB/s]
#
# Downloading (…)"pytorch_model.bin";:  41%|████      | 493M/1.22G [00:06<00:08, 80.6MB/s]
#
# Downloading (…)"pytorch_model.bin";:  41%|████▏     | 503M/1.22G [00:06<00:08, 80.6MB/s]
#
# Downloading (…)"pytorch_model.bin";:  42%|████▏     | 514M/1.22G [00:06<00:08, 81.0MB/s]
#
# Downloading (…)"pytorch_model.bin";:  43%|████▎     | 524M/1.22G [00:06<00:08, 83.5MB/s]
#
# Downloading (…)"pytorch_model.bin";:  44%|████▍     | 535M/1.22G [00:08<00:34, 19.9MB/s]
#
# Downloading (…)"pytorch_model.bin";:  45%|████▍     | 545M/1.22G [00:08<00:25, 25.8MB/s]
#
# Downloading (…)"pytorch_model.bin";:  47%|████▋     | 566M/1.22G [00:08<00:15, 41.6MB/s]
#
# Downloading (…)"pytorch_model.bin";:  47%|████▋     | 577M/1.22G [00:08<00:13, 46.8MB/s]
#
# Downloading (…)"pytorch_model.bin";:  48%|████▊     | 587M/1.22G [00:08<00:12, 51.7MB/s]
#
# Downloading (…)"pytorch_model.bin";:  49%|████▉     | 598M/1.22G [00:08<00:10, 57.1MB/s]
#
# Downloading (…)"pytorch_model.bin";:  50%|█████     | 608M/1.22G [00:09<00:09, 61.8MB/s]
#
# Downloading (…)"pytorch_model.bin";:  51%|█████     | 619M/1.22G [00:09<00:08, 66.8MB/s]
#
# Downloading (…)"pytorch_model.bin";:  52%|█████▏    | 629M/1.22G [00:09<00:08, 69.3MB/s]
#
# Downloading (…)"pytorch_model.bin";:  53%|█████▎    | 640M/1.22G [00:09<00:08, 69.4MB/s]
#
# Downloading (…)"pytorch_model.bin";:  53%|█████▎    | 650M/1.22G [00:10<00:15, 37.6MB/s]
#
# Downloading (…)"pytorch_model.bin";:  54%|█████▍    | 661M/1.22G [00:10<00:12, 45.3MB/s]
#
# Downloading (…)"pytorch_model.bin";:  56%|█████▌    | 682M/1.22G [00:10<00:08, 64.4MB/s]
#
# Downloading (…)"pytorch_model.bin";:  57%|█████▋    | 692M/1.22G [00:10<00:07, 67.5MB/s]
#
# Downloading (…)"pytorch_model.bin";:  58%|█████▊    | 703M/1.22G [00:10<00:07, 71.3MB/s]
#
# Downloading (…)"pytorch_model.bin";:  59%|█████▊    | 713M/1.22G [00:10<00:07, 69.1MB/s]
#
# Downloading (…)"pytorch_model.bin";:  59%|█████▉    | 724M/1.22G [00:10<00:06, 70.6MB/s]
#
# Downloading (…)"pytorch_model.bin";:  60%|██████    | 734M/1.22G [00:10<00:06, 74.6MB/s]
#
# Downloading (…)"pytorch_model.bin";:  61%|██████    | 744M/1.22G [00:11<00:06, 74.4MB/s]
#
# Downloading (…)"pytorch_model.bin";:  62%|██████▏   | 755M/1.22G [00:11<00:06, 75.2MB/s]
#
# Downloading (…)"pytorch_model.bin";:  63%|██████▎   | 765M/1.22G [00:12<00:17, 25.6MB/s]
#
# Downloading (…)"pytorch_model.bin";:  64%|██████▍   | 776M/1.22G [00:12<00:13, 32.0MB/s]
#
# Downloading (…)"pytorch_model.bin";:  66%|██████▌   | 797M/1.22G [00:12<00:08, 50.2MB/s]
#
# Downloading (…)"pytorch_model.bin";:  66%|██████▋   | 807M/1.22G [00:12<00:07, 55.2MB/s]
#
# Downloading (…)"pytorch_model.bin";:  67%|██████▋   | 818M/1.22G [00:12<00:06, 60.1MB/s]
#
# Downloading (…)"pytorch_model.bin";:  68%|██████▊   | 828M/1.22G [00:12<00:05, 65.5MB/s]
#
# Downloading (…)"pytorch_model.bin";:  69%|██████▉   | 839M/1.22G [00:13<00:05, 68.7MB/s]
#
# Downloading (…)"pytorch_model.bin";:  70%|██████▉   | 849M/1.22G [00:14<00:20, 18.2MB/s]
#
# Downloading (…)"pytorch_model.bin";:  71%|███████   | 860M/1.22G [00:14<00:15, 23.4MB/s]
#
# Downloading (…)"pytorch_model.bin";:  72%|███████▏  | 881M/1.22G [00:15<00:09, 35.3MB/s]
#
# Downloading (…)"pytorch_model.bin";:  73%|███████▎  | 891M/1.22G [00:15<00:08, 40.2MB/s]
#
# Downloading (…)"pytorch_model.bin";:  74%|███████▍  | 902M/1.22G [00:15<00:06, 46.2MB/s]
#
# Downloading (…)"pytorch_model.bin";:  75%|███████▌  | 912M/1.22G [00:15<00:05, 52.8MB/s]
#
# Downloading (…)"pytorch_model.bin";:  76%|███████▌  | 923M/1.22G [00:15<00:05, 58.1MB/s]
#
# Downloading (…)"pytorch_model.bin";:  77%|███████▋  | 933M/1.22G [00:15<00:04, 64.0MB/s]
#
# Downloading (…)"pytorch_model.bin";:  78%|███████▊  | 944M/1.22G [00:15<00:04, 66.7MB/s]
#
# Downloading (…)"pytorch_model.bin";:  78%|███████▊  | 954M/1.22G [00:16<00:04, 53.1MB/s]
#
# Downloading (…)"pytorch_model.bin";:  80%|████████  | 975M/1.22G [00:16<00:03, 75.5MB/s]
#
# Downloading (…)"pytorch_model.bin";:  81%|████████  | 986M/1.22G [00:16<00:03, 73.8MB/s]
#
# Downloading (…)"pytorch_model.bin";:  82%|████████▏ | 996M/1.22G [00:16<00:02, 75.1MB/s]
#
# Downloading (…)"pytorch_model.bin";:  83%|████████▎ | 1.01G/1.22G [00:16<00:02, 76.7MB/s]
#
# Downloading (…)"pytorch_model.bin";:  84%|████████▎ | 1.02G/1.22G [00:16<00:02, 79.6MB/s]
#
# Downloading (…)"pytorch_model.bin";:  85%|████████▍ | 1.03G/1.22G [00:16<00:02, 80.2MB/s]
#
# Downloading (…)"pytorch_model.bin";:  85%|████████▌ | 1.04G/1.22G [00:17<00:02, 79.4MB/s]
#
# Downloading (…)"pytorch_model.bin";:  86%|████████▌ | 1.05G/1.22G [00:17<00:02, 76.0MB/s]
#
# Downloading (…)"pytorch_model.bin";:  87%|████████▋ | 1.06G/1.22G [00:17<00:01, 78.5MB/s]
#
# Downloading (…)"pytorch_model.bin";:  88%|████████▊ | 1.07G/1.22G [00:17<00:01, 76.4MB/s]
#
# Downloading (…)"pytorch_model.bin";:  89%|████████▉ | 1.08G/1.22G [00:17<00:01, 77.4MB/s]
#
# Downloading (…)"pytorch_model.bin";:  90%|████████▉ | 1.09G/1.22G [00:17<00:01, 77.7MB/s]
#
# Downloading (…)"pytorch_model.bin";:  91%|█████████ | 1.10G/1.22G [00:17<00:01, 79.6MB/s]
#
# Downloading (…)"pytorch_model.bin";:  91%|█████████▏| 1.11G/1.22G [00:18<00:01, 81.2MB/s]
#
# Downloading (…)"pytorch_model.bin";:  92%|█████████▏| 1.12G/1.22G [00:18<00:01, 81.3MB/s]
#
# Downloading (…)"pytorch_model.bin";:  93%|█████████▎| 1.13G/1.22G [00:18<00:01, 78.8MB/s]
#
# Downloading (…)"pytorch_model.bin";:  94%|█████████▍| 1.14G/1.22G [00:18<00:00, 77.8MB/s]
#
# Downloading (…)"pytorch_model.bin";:  95%|█████████▍| 1.15G/1.22G [00:18<00:00, 76.9MB/s]
#
# Downloading (…)"pytorch_model.bin";:  96%|█████████▌| 1.16G/1.22G [00:18<00:00, 77.0MB/s]
#
# Downloading (…)"pytorch_model.bin";:  97%|█████████▋| 1.17G/1.22G [00:18<00:00, 77.4MB/s]
#
# Downloading (…)"pytorch_model.bin";:  97%|█████████▋| 1.18G/1.22G [00:19<00:00, 79.3MB/s]
#
# Downloading (…)"pytorch_model.bin";:  98%|█████████▊| 1.20G/1.22G [00:19<00:00, 80.1MB/s]
#
# Downloading (…)"pytorch_model.bin";:  99%|█████████▉| 1.21G/1.22G [00:19<00:00, 77.3MB/s]
#
# Downloading (…)"pytorch_model.bin";: 100%|██████████| 1.22G/1.22G [00:19<00:00, 62.6MB/s]
#
# Fetching 15 files: 100%|██████████| 15/15 [00:19<00:00,  1.31s/it]
# {'requires_safety_checker'} was not found in config. Values will be initialized to default values.
# /usr/local/lib/python3.8/dist-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# {'scaling_factor'} was not found in config. Values will be initialized to default values.
# {'prediction_type'} was not found in config. Values will be initialized to default values.
# Configuration saved in /content/drive/MyDrive/Colab_Notebooks/model_index.json
# Configuration saved in /content/drive/MyDrive/Colab_Notebooks/vae/config.json
# Model weights saved in /content/drive/MyDrive/Colab_Notebooks/vae/diffusion_pytorch_model.bin
# Configuration saved in /content/drive/MyDrive/Colab_Notebooks/unet/config.json
# Model weights saved in /content/drive/MyDrive/Colab_Notebooks/unet/diffusion_pytorch_model.bin
# Configuration saved in /content/drive/MyDrive/Colab_Notebooks/scheduler/scheduler_config.json
# Steps: 100%|██████████| 400/400 [10:18<00:00,  1.55s/it, loss=0.252, lr=5e-6]

# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
# !ls -lah /content/drive/MyDrive/Colab_Notebooks
# Out:
# total 4.4M
# drwx------ 2 root root 4.0K Mar  5 14:06  Chebakia
# -rw------- 1 root root 149K Mar  5 16:34  ControlNet_chebakia.ipynb
# -rw------- 1 root root 314K Nov 25  2021 'Copie de forecast_to_power.ipynb'
# drwx------ 2 root root 4.0K Feb  7 12:31  deepL
# -rw------- 1 root root  33K Apr 23  2021  demo_read_data.ipynb
# -rw------- 1 root root  353 Mar 11  2022  DialogueRNN.ipynb
# -rw------- 1 root root 176K Mar 15  2022  distilbert-base-uncased-emotion.ipynb
# drwx------ 2 root root 4.0K Mar  5 16:34  feature_extractor
# -rw------- 1 root root 232K Oct 28  2021 'forecast_to_power (1).ipynb'
# -rw------- 1 root root 922K Jun 27  2022  forecast_to_power.ipynb
# drwx------ 3 root root 4.0K Mar  5 16:12  logs
# -rw------- 1 root root 8.2K May 30  2022  ML_to_power.ipynb
# -rw------- 1 root root  584 Mar  5 16:34  model_index.json
# -rw------- 1 root root 2.3M Aug 11  2022  PrevisionPVRenardieres.ipynb
# drwx------ 2 root root 4.0K Mar  5 16:34  safety_checker
# drwx------ 2 root root 4.0K Mar  5 16:34  scheduler
# drwx------ 2 root root 4.0K Mar  5 16:34  text_encoder
# -rw------- 1 root root  46K May 31  2022  TIPE-CODE.ipynb
# drwx------ 2 root root 4.0K Mar  5 16:34  tokenizer
# -rw------- 1 root root 163K Dec  2  2021 ' Tweet Emotion Recognition.ipynb'
# drwx------ 2 root root 4.0K Mar  5 16:34  unet
# drwx------ 2 root root 4.0K Mar  5 16:34  vae

# %%
from diffusers import StableDiffusionPipeline
import torch

model_id = "/content/drive/MyDrive/Colab_Notebooks/Chebakia/model"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16).to("cuda")

prompt = "girl taking a cookie"
image = pipe(prompt, num_inference_steps=20, guidance_scale=2).images[0]

image
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F16A5C26AF0>

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) Y
# Token is valid.
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from huggingface_hub import Repository
repo = Repository(local_dir="ay7aja", clone_from="asmaekhald/chebakia-diffusion")
# Out:
# Cloning https://huggingface.co/asmaekhald/chebakia-diffusion into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/asmaekhald/chebakia-diffusion into local empty directory.

# %%
# !cp -r /content/drive/MyDrive/Colab_Notebooks/Chebakia/model /content/ay7aja

# %%
repo.git_pull(rebase=True)

# %%
repo.push_to_hub("add model")
# Out:
# Upload file model/unet/diffusion_pytorch_model.bin:   0%|          | 32.0k/3.20G [00:00<?, ?B/s]
# Upload file model/vae/diffusion_pytorch_model.bin:   0%|          | 32.0k/319M [00:00<?, ?B/s]
# Upload file model/logs/dreambooth/1678033281.0256798/events.out.tfevents.1678033281.2ed6d4c9915f.5596.1: 100%|…
# Upload file model/logs/dreambooth/events.out.tfevents.1678033447.2ed6d4c9915f.6335.0:  49%|####9     | 32.0k/6…
# Upload file model/logs/dreambooth/1678033447.0557222/events.out.tfevents.1678033447.2ed6d4c9915f.6335.1: 100%|…
# Upload file model/text_encoder/pytorch_model.bin:   0%|          | 32.0k/235M [00:00<?, ?B/s]
# Upload file model/logs/dreambooth/1678032753.431704/events.out.tfevents.1678032753.2ed6d4c9915f.3181.1: 100%|#…
# Upload file model/safety_checker/pytorch_model.bin:   0%|          | 32.0k/1.13G [00:00<?, ?B/s]
# Upload file model/logs/dreambooth/1678033128.0417457/events.out.tfevents.1678033128.2ed6d4c9915f.4853.1: 100%|…
# Upload file model/logs/dreambooth/1678032928.041292/events.out.tfevents.1678032928.2ed6d4c9915f.3985.1: 100%|#…
# Upload file model/logs/dreambooth/events.out.tfevents.1678033280.2ed6d4c9915f.5596.0: 100%|##########| 166/166…
# Upload file model/logs/dreambooth/events.out.tfevents.1678033127.2ed6d4c9915f.4853.0: 100%|##########| 166/166…
# Upload file model/logs/dreambooth/events.out.tfevents.1678032928.2ed6d4c9915f.3985.0: 100%|##########| 88.0/88…
# Upload file model/logs/dreambooth/events.out.tfevents.1678032753.2ed6d4c9915f.3181.0: 100%|##########| 88.0/88…
# remote: Scanning LFS files of refs/heads/main for validity...
# remote: LFS file scan complete.
# To https://huggingface.co/asmaekhald/chebakia-diffusion
#    d104269..de6e2c3  main -> main
#
# WARNING:huggingface_hub.repository:remote: Scanning LFS files of refs/heads/main for validity...
# remote: LFS file scan complete.
# To https://huggingface.co/asmaekhald/chebakia-diffusion
#    d104269..de6e2c3  main -> main
# 'https://huggingface.co/asmaekhald/chebakia-diffusion/commit/de6e2c3626328454f7be23c10b8d6d551eedf2f6'

# %% [markdown]
# Trying with this finetuned model + ControlNet

# %%
# !pip install -q opencv-contrib-python
# !pip install -q controlnet_aux
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 KB 4.7 MB/s eta 0:00:00

# %%
from diffusers import StableDiffusionControlNetPipeline, ControlNetModel
import torch

controlnet = ControlNetModel.from_pretrained("lllyasviel/sd-controlnet-canny", torch_dtype=torch.float16)
# Out:
# WARNING:xformers:A matching Triton is not available, some optimizations will not be enabled.
# Error caught was: No module named 'triton'

# %%
from diffusers import UniPCMultistepScheduler

# %%
# !pip install -q diffusers==0.14.0 transformers xformers git+https://github.com/huggingface/accelerate.git
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 737.4/737.4 KB 12.7 MB/s eta 0:00:00
#   Building wheel for accelerate (pyproject.toml) ... done

# %%
#model_id = "sd-dreambooth-library/mr-potato-head"
model_id = "/content/drive/MyDrive/Colab_Notebooks/Chebakia/model"
pipe = StableDiffusionControlNetPipeline.from_pretrained(
    model_id,
    controlnet=controlnet,
    torch_dtype=torch.float16,
)
pipe.scheduler = UniPCMultistepScheduler.from_config(pipe.scheduler.config)
pipe.enable_model_cpu_offload()
pipe.enable_xformers_memory_efficient_attention()

# %%
from diffusers.utils import load_image

image = load_image(
    "https://hf.co/datasets/huggingface/documentation-images/resolve/main/diffusers/input_image_vermeer.png"
)
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F3162008B20>

# %%
import cv2
from PIL import Image
import numpy as np

image = np.array(image)

low_threshold = 100
high_threshold = 200

image = cv2.Canny(image, low_threshold, high_threshold)
image = image[:, :, None]
image = np.concatenate([image, image, image], axis=2)
canny_image = Image.fromarray(image)
canny_image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F31622D74F0>

# %%
generator = torch.manual_seed(2)
prompt = "a photo of cookie, best quality, extremely detailed"
output = pipe(
    prompt,
    canny_image,
    negative_prompt="monochrome, lowres, bad anatomy, worst quality, low quality",
    generator=generator,
    num_inference_steps=20,
)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
output.images[0]
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F3160BEBD90>
